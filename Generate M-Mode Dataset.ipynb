# %%
from tqdm.notebook import trange, tqdm

import torch
import torch.utils.data as data

import os
from glob import glob
import os.path as osp

import numpy as np
from skimage import io

from skimage.measure import label, regionprops_table
import pandas
from PIL import Image

# %%
class DataGenDataset(data.Dataset):

    def __init__(self,
                 root_fp='/media/miro/4tb_cached/usg_data/base_dataset/',
                 mask_dir_name="lung_mask_ss",
                 transform=None,
                 number_of_frames=32,
                 step = 16,
                 load2ram = False):
        super(DataGenDataset, self).__init__()
        self.transform = transform
        self.number_of_frames = number_of_frames
        self.step = step

        self.image_list = sorted(glob(os.path.join(root_fp, 'frames/*/*/*.png')))
        self.mask_list = [fp.replace("/frames/","/"+mask_dir_name+"/") for fp in self.image_list]

        self.classes, self.identifiers, self.frame_list, self.data, self.mask_data = \
            list(), list(), list(), dict(), dict()

        nos = len(self.image_list)
        idx = 0
        while idx < nos:
            if idx + self.number_of_frames < nos:
                if os.path.dirname(self.image_list[idx]) in os.path.dirname(self.image_list[idx + self.number_of_frames]):
                    self.frame_list += [self.image_list[idx:idx + self.number_of_frames]]
                    self.identifiers += [os.path.dirname(self.image_list[idx])]
            idx = idx+self.step

        for idx in tqdm(range(nos)):
            if "lung_sliding_absence" in self.image_list[idx]:
                self.classes += [1]
            else:
                self.classes+= [0]

            if load2ram:
                self.data[self.image_list[idx]] = io.imread(self.image_list[idx])
                self.mask_data[self.image_list[idx]] = io.imread(self.mask_list[idx])
            else:
                self.data[self.image_list[idx]] = Image.open(self.image_list[idx])
                self.mask_data[self.image_list[idx]] = Image.open(self.mask_list[idx])


    def __getitem__(self, index):
        frames = self.frame_list[index]

        img = np.zeros((self.number_of_frames,480,480))
        mask = np.zeros((256,256))

        for idx, frame in enumerate(frames):
            img[idx,:,:] = np.array(self.data[frame])

        mask[:,:] = self.mask_data[frames[self.number_of_frames//2]]

        if self.transform:
            img = self.transform(img)

        return img, mask, self.frame_list[index][0]

    def __len__(self):
        return len(self.frame_list)

    def get_class_vector(self, indices):
        im_classes = []
        for index in indices:
            if "lung_sliding_absence" in self.image_list[index]:
                im_classes += [1]
            else:
                im_classes += [0]
        return np.array(im_classes)

# %%
from skimage.measure import label, regionprops_table
from skimage.morphology import binary_opening,rectangle
from skimage import transform
import matplotlib.pyplot as plt

# %%
steps = [8]
nofs = [8]
for idx,nof in enumerate(nofs):
    dataset = DataGenDataset(root_fp = "/home/jin/Documents/miro/data/base_dataset/",number_of_frames=nof,step=steps[idx],load2ram= True)
    for i in tqdm(range(len(dataset))):
        img,mask,path = dataset.__getitem__(i)
        new_path = path.replace("/frames/","/mmode/"+str(dataset.number_of_frames)+"/")
        if not os.path.exists(os.path.dirname(new_path)):
            os.makedirs(os.path.dirname(new_path))

        im  = binary_opening(transform.resize(mask,(480,480)),rectangle(5,5))
        #plt.imshow(im)
        #plt.figure()
        label_image = label(im)
        if np.max(label_image)>0:
            #plt.subplot(122)
            #plt.imshow(label_image)
            regions = regionprops_table(label_image,properties=('label', 'bbox'))
            #plt.axvline(regions['bbox-1'][0])
            #plt.axvline(regions['bbox-3'][0])

            slices = np.arange(regions['bbox-1'][0],regions['bbox-3'][0])
            for slice in slices:
                mmode = img[:,:,slice].transpose(1,0)
                #plt.subplot(121)
                if np.max(mmode) !=0:
                    io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=17386.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2126.0), HTML(value='')))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0006_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0006_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0022_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0022_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0054_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0054_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0086_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0086_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0102_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0102_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0110_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0110_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0126_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0126_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0150_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0150_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0158_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0158_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0166_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0166_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0198_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0198_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0246_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171128_114540_574/frame0246_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0007_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0007_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0015_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0015_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0023_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0023_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0031_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0031_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0039_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0039_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0047_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0047_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0055_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0055_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0063_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0063_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0071_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0071_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0079_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0079_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0087_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0087_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0095_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0095_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0103_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0103_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0111_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0111_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0119_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0119_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0127_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0127_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0135_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0135_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0143_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0143_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0151_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0151_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0159_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0159_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0167_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0167_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0175_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0175_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0183_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0183_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0191_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0191_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0199_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0199_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0207_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0207_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0215_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0215_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0223_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0223_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0231_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0231_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0239_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0239_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0247_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0247_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0255_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0255_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0263_0.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
# <ipython-input-4-fe02f23dfeed>:27: UserWarning: /home/jin/Documents/miro/data/base_dataset/mmode/8/lung_sliding_presence/20171129_160652_595/frame0263_1.png is a low contrast image
#   io.imsave(new_path.replace(".png","_"+str(slice)+".png"),mmode.astype(np.uint8))
